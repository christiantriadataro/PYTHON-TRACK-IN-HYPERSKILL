# %% [markdown]
# ## Analytics as an Integral Part of the Decision-Making Ecosystem
# Critical key components for a successful analytics solution:
# - Data collection
# - Integration with multiple data sources
# - ability to create and manage single source of truth (unique identifiers) - single reference/repository
# - hardware sizing, performance considerations, and scalability - is it sufficient to continue to the operation?
# scalability - to grow the business to what extent?
# ################
# -
# Three types of analytics
# descriptive - what has happened?
# prescriptive - what should happen?
# predictive - what will happen?
#
# ##########
# Descriptive analytics
# provides information about the past state or performance of a business and its environment
#
# Predictive analytics
# helps predict (based on data and statistical techniques) with confidence what will happen next so that you can make well-informed decisions and improve business outcomes.
# - uses simulation models to suggest what could happen.
#
# Prescriptive analytics
# recommended high-value alternative actions or decisions given a complex set of targets, limits, and choices.
# predicts future outcomes and suggest courses of actions to take so that you can benefit from those predictions.
#
# TWo fundamentals approaches to finding business opportunities
# outside in thinking - keeping tabs on what others in your industry are doing.
# - what makes the business tick?
# - where does the next breakthough await?
#
# inside-out thinking: keeping a systematic inventory of the key business
# - how are key decisions made within?
# - what are the key business decisions?
# - how they can made more process-oriented?
#
# outside thinking
# what the customer want?
#
# inside thinking
# what are the capability of the organization
#
# Samples of most common business challeneges
# - increase market share (customer acquisition)
# - increase customer intimacy
# - increase customer satisfaction and retention
# - increase customer wallet share growth
# - increase customer profitability
# - increase traffic and conversion,
# - increase employee productivity and performance.
# - reduce cost
#
#
# building analytic culture
# do individuals use gut instinct more than they rely on facts, numbers?
#
# does everyone in the org understand and appreciate how they use analytics to substantiate their decisions
#
#
# building an analytics culture
#
# managers
# to build the employees
#
# employees to use managers
#
# building an analytics culture
# define->assess->select->implement
# analytics solution life cycle
#
# define
# the problem
# objective
#
# assess
# the goal?
# main goal?
# the sub goal?
# priorities?
# identify how teh big the problem is
# and how to break it down and solve it better
#
# came up with different approach
#
#
# implement the approach
#
#
# building an analytics culture
# - search for the truth
# - find or identify patterns and get to root causes
# - make data as granular as possible in their analysis
# - seek data, not just stories to analyze a question or issue
# - value negative resutls as well as postive
# - use the results of analysis to make decisions and take actions
# - are pragmatic about trade-offs in decision making
#
#
# analytic culture - the sum total of a series of individual atttributes and behaviors that get repeated over time. People in a nalytical culture
#
# search for the truth - analytically minded people dont accept traditional actions as "given", but try to find our what's really
# how we can solve the problem by the data
#
# find or indentify patterns and get to root causes
# so we can directly address it
#
# make data as granular as possible in their analysis
# address
# (zipcode, address, city, region)
#
# seek data, not just stories, to analyze a question or issue
# - what happended in this month? what are the marketing strategy and how we can solve it
#
# value negative results as well as positive
# good feedback and bad feedback
#
# use the results of analysis to make decision and take actions
# - identify pattern in the daata
#
# are pragmatic bout trade-offs in decision making
# - timely decision and available data to provide,

# %% [markdown]
# Inventory Modules:
# - Product Management
# - Sales and Stocks Management
# - Order Management
# - Revenue and Expenses Management
# POS Modules:
#
# Ordering Modules:
# - Shopping Management
# - Customer Management
# - Transaction Management
# - Report Management
#
# E-commerce Modules:
# - Customer Management
# - Stocks and Sales
# - Product Management
# - Payments and Deliveries
#
# BBMC:
# - Order Management
# - Account Management
# - Product Management
# - Deliveries Management
# - Transaction/Payment Management
# - Refund Management
# - Report Management

# %% [markdown]
# Order Management:
#     Frontend:
#         Customer:
#             - Store Page:
#                 - List of Product Cards
#                 - Sort by category
#             - Product Details Page:
#                 - Product Image
#                 - Product Price
#                 - Product Details
#                 - Add to Cart Button
#             - Order Status Page:
#                 - List of Purchased Products
#                     - Purchased Products:
#                     - Order Status
#                     - Order Details
#             - Cart Page:
#                 - List of Ordered Products
#                 - Checkout Button
#             - Payment Page:
#                - Customer Address Form
#                     - Customer Name
#                     - Contact Number
#                     - Address
#                - Payment Method Select Button
#                     - GCash
#                     - Bank Transfer
#                - File Attached
#                - Product Details
#                - Checkout Button
#     Backend:
#         - Forms Validation
#         - Account Logging
#         - Page Routing
#         - Page Authorization
#         - Database Table
#         - Database Connection
#
# Account Management:
#     Frontend:
#         Customer:
#             - Account Profile:
#                 - Form:
#                     - Account Image
#                     - Name
#                     - Email
#                 - Save, and Back Buttons
#         Admin, Owner:
#             - Account Page:
#                 - List of Accounts:
#                 - Forms/Columns:
#                     - Account Name
#                     - Email
#                     - Account Type
#                     - Date of Creation
#                 - Edit and Delete Buttons (it depends on account type)
#     Backend:
#         - Account Logging
#         - Page Routing
#         - Page Authorization
#         - Database Table
#         - Database Connection
#
# Product Management:
#     Frontend:
#         Admin, Staff:
#             - Product Page:
#                 - List of Products:
#                 - Forms/Columns:
#                     - Product
#                     - Size
#                     - Date of Expiration
#                     - Price
#                     - Stock
#                     - Status (Unavailable, Available)
#                     - Operations (Edit, Delete)
#                  - Import Products
#                 - Status Buttons
#                 - Edit and Delete Buttons
#     Backend:
#     - Account Logging
#     - Page Routing
#     - Page Authorization
#     - Database Table
#     - Database Connection
# Delivery Management:
#     Frontend:
#         - Delivery Page:
#             - List of Deliveries:
#             - Forms/Columns:
#                 - Product
#                 - Name of Customer
#                 - Date of Delivery
#                 - Quantity of Products
#                 - Status (Pending, Paid, unsettled)
#                 - Operations (Edit, Delete)
#             - Status Buttons
#             - Edit and Delete Buttons
#     Backend:
#     - Account Logging
#     - Page Routing
#     - Page Authorization
#     - Database Table
#     - Database Connection
#
# Transaction Management:
#     Frontend:
#         - Transaction Page:
#             - List of Transactions:
#             - Forms/Columns:
#                 - Product
#                 - Name of Customer
#                 - Date of Purchased
#                 - Quantity of Products
#                 - Operations (Edit, Delete)
#             - Edit and Delete Buttons
#     Backend:
#     - Account Logging
#     - Page Routing
#     - Page Authorization
#     - Database Table
#     - Database Connection
#
# Refund Management:
#     Frontend:
#         - Delivery Page:
#             - List of Deliveries:
#             - Forms/Columns:
#                 - Product
#                 - Name of Customer
#                 - Date of Refunded
#                 - Quantity of Products
#                 - Refund Description
#                 - Status (Pending, Approved, Rejected)
#                 - Operations (Edit, Delete)
#             - Status Buttons
#             - Edit and Delete Buttons
#     Backend:
#     - Account Logging
#     - Page Routing
#     - Page Authorization
#     - Database Table
#     - Database Connection
#
# Report/Analytics Management:
#     Frontend:
#         - Dashboard
#             - List of Data Report Cards
#             - Refresh Button
#         - Report Product Page:
#             - List of products
#             - Columns:
#                 - Demand by month
#                 - Demand by year
#                 - Expected demand by month
#                 - Expected demand by year
#             - Sort by [month]-[month]/[year]-[year]
#     Backend:
#     - Account Logging
#     - Page Routing
#     - Page Authorization
#     - Database Table
#     - Database Connection

# %%
import pandas as pd

print()
